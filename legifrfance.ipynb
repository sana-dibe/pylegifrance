# %% [markdown]
# ## Légifrance data

# %% [markdown]
# ### Preprocess data

# %%
from pylegifrance import LegiHandler
import config2py

client = LegiHandler()
client.set_api_keys(legifrance_api_key=config2py.config_getter("LEGIFRANCE_CLIENT_ID"), legifrance_api_secret=config2py.config_getter("LEGIFRANCE_CLIENT_SECRET"))
# Out:
# 2024-02-21 10:41:04,705 - root - INFO - Connexion à l'api legifrance réussie.

# %%
from pylegifrance import recherche_CODE

doc_integrale_travail = recherche_CODE(code_name="Code du travail")
# Out:
# 2024-02-21 10:41:12,986 - pylegifrance.process.processors - INFO - Nombre de résultats trouvés: 1

# %%
len(doc_integrale_travail[0])
# Out:
# 41

# %%
doc_integrale_travail[0].keys()
# Out:
# dict_keys(['executionTime', 'dereferenced', 'id', 'idConteneur', 'cid', 'title', 'nor', 'eli', 'alias', 'jorfText', 'jurisState', 'visa', 'modifDate', 'jurisDate', 'dateDebutVersion', 'dateFinVersion', 'signers', 'prepWork', 'dateParution', 'dateTexte', 'numParution', 'notice', 'nota', 'inap', 'textNumber', 'textAbroge', 'etat', 'dossiersLegislatifs', 'nature', 'resume', 'rectificatif', 'motsCles', 'appellations', 'liens', 'observations', 'sections', 'articles', 'pagePdf', 'fileName', 'fileSize', 'filePath'])

# %%
## Voir le contenu de doc_integrale
import json

with open('code_travail.json', 'w', encoding='utf-8') as fichier:
    json.dump(doc_integrale_travail, fichier, ensure_ascii=False, indent=4)

# %%
def extraire_infos(element, infos=[]):
    if isinstance(element, dict):
        if 'pathTitle' in element and 'content' in element:
            infos.append({
                'pathTitle': element['pathTitle'],
                'content': element['content']
            })

        for key, value in element.items():
            extraire_infos(value, infos)

    elif isinstance(element, list):
        for item in element:
            extraire_infos(item, infos)

    return infos

# %%
infos_extraites_code_travail = extraire_infos(doc_integrale_travail[0]['sections'])

# %%
len(infos_extraites_code_travail)
# Out:
# 11520

# %%
for info in infos_extraites_code_travail[:5]:
    print(info)
# Out:
# {'pathTitle': ['Partie réglementaire  ', 'Première partie : Les relations individuelles de travail ', 'Livre Ier : Dispositions préliminaires ', "Titre Ier : Champ d'application et calcul des seuils d'effectifs", ' Chapitre unique'], 'content': "<p>En application de l'article <a href='/affichCodeArticle.do?cidTexte=LEGITEXT000006072050&idArticle=LEGIARTI000006900783&dateTexte=&categorieLien=cid'>L. 1111-2</a>, les salariés mis à disposition par une entreprise de travail temporaire, un groupement d'employeurs ou une association intermédiaire ne sont pas pris en compte pour le calcul des effectifs de l'entreprise utilisatrice pour l'application des dispositions légales relatives à la tarification des risques accident du travail et maladie professionnelle qui se réfèrent à une condition d'effectif.</p>"}
# {'pathTitle': ['Partie réglementaire  ', 'Première partie : Les relations individuelles de travail ', 'Livre Ier : Dispositions préliminaires ', 'Titre IV : Egalité professionnelle entre les femmes et les hommes ', 'Chapitre II : Dispositions générales'], 'content': "<p><br/>Les emplois et activités professionnelles pour l'exercice desquels l'appartenance à l'un ou l'autre sexe constitue la condition déterminante sont les suivants :<br/> 1° Artistes appelés à interpréter soit un rôle féminin, soit un rôle masculin ;<br/> 2° Mannequins chargés de présenter des vêtements et accessoires ;<br/> 3° Modèles masculins et féminins.</p>"}
# {'pathTitle': ['Partie réglementaire  ', 'Première partie : Les relations individuelles de travail ', 'Livre Ier : Dispositions préliminaires ', 'Titre IV : Egalité professionnelle entre les femmes et les hommes ', "Chapitre II bis : Mesures visant à supprimer les écarts de rémunération entre les femmes et les hommes dans l'entreprise et à assurer une répartition équilibrée de chaque sexe parmi les cadres dirigeants et les membres des instances dirigeantes", 'Annexes'], 'content': "<p>MODALITÉS DE CALCUL ET D'ÉVALUATION DES INDICATEURS DÉFINIS À L'ARTICLE <a href='/affichCodeArticle.do?cidTexte=LEGITEXT000006072050&idArticle=LEGIARTI000038024424&dateTexte=&categorieLien=cid' title='Code du travail - art. D1142-2 (V)'>D. 1142-2 </a>POUR LES ENTREPRISES DE PLUS DE 250 SALARIÉS </p><p><br/>1. Période de référence <br/><p> <br/>L'employeur peut choisir la période de douze mois consécutifs servant de période de référence pour le calcul des indicateurs. <br/><p> <br/>Les indicateurs sont calculés chaque année par l'employeur, au plus tard le 1er mars de l'année en cours, à partir des données de la période de référence annuelle choisie par l'employeur qui précède l'année de publication des indicateurs. <br/><p> <br/>2. Salariés à prendre en compte pour le calcul des indicateurs <br/><p> <br/>L'effectif des salariés à prendre en compte pour le calcul des indicateurs est apprécié sur la période de référence annuelle choisie par l'employeur. <br/><p> <br/>Les apprentis, les titulaires d'un contrat de professionnalisation, les salariés mis à la disposition de l'entreprise par une entreprise extérieure, les salariés expatriés, ainsi que les salariés absents plus de la moitié de la période de référence annuelle considérée ne sont pas pris en compte dans les effectifs de l'entreprise pour le calcul des indicateurs. <br/><p> <br/>Les caractéristiques individuelles des salariés suivantes sont appréciées au dernier jour de la période de référence annuelle choisie par l'employeur ou au dernier jour de présence du salarié dans l'entreprise :</p><p><br/>-l'âge ;<br/><p> <br/>-le niveau ou coefficient hiérarchique en application de la classification de branche ;<br/><p> <br/>-le niveau selon la méthode de cotation des postes de l'entreprise ;<br/><p> <br/>-la catégorie socioprofessionnelle. </p><p><br/>3. Eléments de la rémunération à prendre en compte pour le calcul des indicateurs <br/><p> <br/>La rémunération de chaque salarié, au sens de l'article <a href='/affichCodeArticle.do?cidTexte=LEGITEXT000006072050&idArticle=LEGIARTI000006902819&dateTexte=&categorieLien=cid' title='Code du travail - art. L3221-3 (V)'>L. 3221-3</a>, est reconstituée en équivalent temps plein sur la période de référence annuelle considérée. Les indemnités de licenciement et de départ à la retraite, les primes liées à une sujétion particulière qui ne concerne pas la personne du salarié, les primes d'ancienneté, les heures supplémentaires, les heures complémentaires, ainsi que les versements effectués au titre de l'intéressement et de la participation ne sont pas pris en compte. <br/><p> <br/>4. Méthode de calcul des indicateurs et barème à appliquer aux résultats ainsi obtenus <br/><p> <br/>Les indicateurs définis à l'article D. 1142-2 sont calculés et évalués selon un barème allant de 0 à 100 points, conformément aux tableaux suivants : <br/><p> <br/>4.1. Indicateur relatif à l'écart de rémunération entre les femmes et les hommes </p><p></p><center><table border='1'><tbody><tr><th><br/>INDICATEUR </th><th><br/>METHODE DE CALCUL </th><th><br/>RESULTATS OBTENUS </th><th><br/>NOMBRE <br/><p> <br/>DE POINTS </th></tr><tr><td rowspan='22' align='left'><br/>Ecart de rémunération entre les femmes et les hommes (1° de l'article D. 1142-2) </td><td rowspan='22' align='justify'><br/>a) Les salariés sont répartis en groupe, selon quatre tranches d'âge et par catégorie de postes équivalents. <br/><p> <br/>Les tranches d'âge sont les suivantes :<br/><p> <br/>-moins de 30 ans ;<br/>< ...
# {'pathTitle': ['Partie réglementaire  ', 'Première partie : Les relations individuelles de travail ', 'Livre Ier : Dispositions préliminaires ', 'Titre IV : Egalité professionnelle entre les femmes et les hommes ', "Chapitre II bis : Mesures visant à supprimer les écarts de rémunération entre les femmes et les hommes dans l'entreprise et à assurer une répartition équilibrée de chaque sexe parmi les cadres dirigeants et les membres des instances dirigeantes", 'Annexes'], 'content': "<p><br/>MODALITÉS DE CALCUL ET D'ÉVALUATION DES INDICATEURS DÉFINIS À L'ARTICLE <a href='/affichCodeArticle.do?cidTexte=LEGITEXT000006072050&idArticle=LEGIARTI000038024473&dateTexte=&categorieLien=cid' title='Code du travail - art. D1142-2-1 (V)'>D. 1142-2-1 </a>POUR LES ENTREPRISES ENTRE 50 ET 250 SALARIÉS </p><p><br/>1. Période de référence <br/>L'employeur peut choisir la période de douze mois consécutifs servant de période de référence pour le calcul des indicateurs. <br/>Les indicateurs sont calculés chaque année par l'employeur, au plus tard le 1er mars de l'année en cours, à partir des données de la période de référence annuelle choisie par l'employeur qui précède l'année de publication des indicateurs. <br/>L'employeur peut décider de calculer l'indicateur relatif aux augmentations individuelles, défini au 2° de l'article D. 1142-2-1, sur une période de référence pluriannuelle, à partir des données des deux ou trois années précédentes. Son caractère pluriannuel peut être révisé tous les trois ans. <br/>2. Salariés à prendre en compte pour le calcul des indicateurs <br/>L'effectif des salariés à prendre en compte pour le calcul des indicateurs est apprécié sur la période de référence annuelle choisie par l'employeur. <br/>Les apprentis, les titulaires d'un contrat de professionnalisation, les salariés mis à la disposition de l'entreprise par une entreprise extérieure, les salariés expatriés, ainsi que les salariés absents plus de la moitié de la période de référence considérée ne sont pas pris en compte dans les effectifs de l'entreprise pour le calcul des indicateurs. <br/>Les caractéristiques individuelles des salariés suivantes sont appréciées au dernier jour de la période de référence annuelle choisie par l'employeur ou au dernier jour de présence du salarié dans l'entreprise :</p><p><br/>-l'âge ;<br/>-le niveau ou coefficient hiérarchique en application de la classification de branche ;<br/>-le niveau selon la méthode de cotation des postes de l'entreprise ;<br/>-la catégorie socioprofessionnelle. </p><p><br/>3. Eléments de la rémunération à prendre en compte pour le calcul des indicateurs <br/>La rémunération de chaque salarié, au sens de l'article <a href='/affichCodeArticle.do?cidTexte=LEGITEXT000006072050&idArticle=LEGIARTI000006902819&dateTexte=&categorieLien=cid' title='Code du travail - art. L3221-3 (V)'>L. 3221-3</a>, est reconstituée en équivalent temps plein sur la période de référence annuelle considérée. Les indemnités de licenciement et de départ à la retraite, les primes liées à une sujétion particulière qui ne concerne pas la personne du salarié, les primes d'ancienneté, les heures supplémentaires, les heures complémentaires, ainsi que les versements effectués au titre de l'intéressement et de la participation ne sont pas pris en compte. <br/>4. Méthode de calcul des indicateurs et barème à appliquer aux résultats ainsi obtenus <br/>Les indicateurs définis à l'article D. 1142-2-1 sont calculés et évalués selon un barème allant de 0 à 100 points, conformément aux tableaux suivants : <br/>4.1. Indicateur relatif à l'écart de rémunération entre les femmes et les hommes </p><p></p><center><table border='1'><tbody><tr><th><br/>INDICATEUR </th><th><br/>METHODE DE CALCUL </th><th><br/>RESULTATS OBTENUS </th><th><br/>NOMBRE <br/>DE POINTS </th></tr><tr><td rowspan='22' align='left'><br/>Ecart de rémunération entre les femmes et les hommes (1° de l'article D. 1142-2-1) </td><td rowspan='22' align='justify'><br/>a) Les salariés sont ...
# {'pathTitle': ['Partie réglementaire  ', 'Première partie : Les relations individuelles de travail ', 'Livre Ier : Dispositions préliminaires ', 'Titre IV : Egalité professionnelle entre les femmes et les hommes ', "Chapitre II bis : Mesures visant à supprimer les écarts de rémunération entre les femmes et les hommes dans l'entreprise et à assurer une répartition équilibrée de chaque sexe parmi les cadres dirigeants et les membres des instances dirigeantes"], 'content': "<p>Pour les entreprises de plus de deux cent cinquante salariés, les indicateurs mentionnés à l'article <a href='/affichCodeArticle.do?cidTexte=LEGITEXT000006072050&idArticle=LEGIARTI000037379277&dateTexte=&categorieLien=cid'>L. 1142-8</a> sont les suivants : <br/><p> <br/>1° L'écart de rémunération entre les femmes et les hommes, calculé à partir de la moyenne de la rémunération des femmes comparée à celle des hommes, par tranche d'âge et par catégorie de postes équivalents ; <br/><p> <br/>2° L'écart de taux d'augmentations individuelles de salaire ne correspondant pas à des promotions entre les femmes et les hommes ; <br/><p> <br/>3° L'écart de taux de promotions entre les femmes et les hommes ; <br/><p> <br/>4° Le pourcentage de salariées ayant bénéficié d'une augmentation dans l'année de leur retour de congé de maternité, si des augmentations sont intervenues au cours de la période pendant laquelle le congé a été pris ; <br/><p> <br/>5° Le nombre de salariés du sexe sous-représenté parmi les dix salariés ayant perçu les plus hautes rémunérations. <br/><p> <br/>Ces indicateurs sont calculés selon les modalités définies à l'annexe I figurant à la fin du présent chapitre. En cas de constitution d'un comité social et économique au niveau d'une unité économique et sociale reconnue par accord collectif ou par décision de justice entre plusieurs entreprises juridiquement distinctes, les indicateurs sont calculés au niveau de l'unité économique et sociale.<br/><p> </p>"}

# %%
## pour sos oxygène, c'est que les données de santé, sécurité sociale, ....
code_sante = recherche_CODE(code_name="Code de la santé publique")
# Out:
# 2024-02-21 10:42:26,727 - pylegifrance.process.processors - INFO - Nombre de résultats trouvés: 1

# %%
infos_extraites_code_sante = extraire_infos(code_sante[0]['sections'])
infos_extraites_code_sante[:2]
# Out:
# [{'pathTitle': ['Partie réglementaire  ',
#    'Première partie : Les relations individuelles de travail ',
#    'Livre Ier : Dispositions préliminaires ',
#    "Titre Ier : Champ d'application et calcul des seuils d'effectifs",
#    ' Chapitre unique'],
#   'content': "<p>En application de l'article <a href='/affichCodeArticle.do?cidTexte=LEGITEXT000006072050&idArticle=LEGIARTI000006900783&dateTexte=&categorieLien=cid'>L. 1111-2</a>, les salariés mis à disposition par une entreprise de travail temporaire, un groupement d'employeurs ou une association intermédiaire ne sont pas pris en compte pour le calcul des effectifs de l'entreprise utilisatrice pour l'application des dispositions légales relatives à la tarification des risques accident du travail et maladie professionnelle qui se réfèrent à une condition d'effectif.</p>"},
#  {'pathTitle': ['Partie réglementaire  ',
#    'Première partie : Les relations individuelles de travail ',
#    'Livre Ier : Dispositions préliminaires ',
#    'Titre IV : Egalité professionnelle entre les femmes et les hommes ',
#    'Chapitre II : Dispositions générales'],
#   'content': "<p><br/>Les emplois et activités professionnelles pour l'exercice desquels l'appartenance à l'un ou l'autre sexe constitue la condition déterminante sont les suivants :<br/> 1° Artistes appelés à interpréter soit un rôle féminin, soit un rôle masculin ;<br/> 2° Mannequins chargés de présenter des vêtements et accessoires ;<br/> 3° Modèles masculins et féminins.</p>"}]

# %%
len(infos_extraites_code_sante)
# Out:
# 25819

# %%
with open('code_sante.json', 'w', encoding='utf-8') as fichier:
    json.dump(infos_extraites_code_sante, fichier, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Create dict with content in text format

# %%
infos_extraites_code_sante[0].keys()
# Out:
# dict_keys(['pathTitle', 'content'])

# %%
## The content is in html format, so I convert it to text using utf8 encoding and I ignore links as they have not a meaning

import html2text

def convert_content(content, ig_links=True):
    h = html2text.HTML2Text()
    h.ignore_links = ig_links
    if isinstance(content, bytes):
        content = content.decode('utf-8')
    return h.handle(content)

converted_infos = []
id_counter = 1 

for item in infos_extraites_code_sante:
    converted_item = {
        'pathTitle': item['pathTitle'],
        'content': convert_content(item['content']),
        'id': f'id{id_counter}' 
    }



    converted_infos.append(converted_item)
    id_counter += 1

# %%
len(converted_infos)
# Out:
# 25819

# %% [markdown]
# ## Chunker (using lkj chunker)

# %%
from typing import Iterable
from lkj import chunker
import oa


def pathTitle_list_to_text(title: list, sep='\n'):
    return sep.join(title)

def pathContent_metadata_to_text(metadata: dict, *, sep='\n'):
    return f"{sep.join(metadata['pathTitle'])}{sep}{metadata['content']}"

# %%
from typing import List, Tuple
import tiktoken

def tokenize(text: str, encoding_name : str ) -> List[str]:
    encoding = tiktoken.get_encoding(encoding_name)
    int_tokens = encoding.encode(text)
    str_tokens = [encoding.decode_single_token_bytes(token) for token in int_tokens]
    return str_tokens

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %% [markdown]
# For the moment, I will skip code that exceeds the maximum token limit

# %%
from lkj import chunker
encoding_name = "cl100k_base" 

def process_data(data: dict, max_tokens: int) -> Tuple[str, dict, bool]:
    code_text = pathContent_metadata_to_text(data)
    code_tokens = num_tokens_from_string(code_text, encoding_name)

    if code_tokens > max_tokens:
        # code_tokens = code_tokens[:max_tokens]
        return "", {}, True  # Skips the code

    # truncated_text = ' '.join(code_tokens)
    # return truncated_text
    metadata = {
        "source": pathTitle_list_to_text(data['pathTitle']),
        "id" : data['id'],
        
    }
    return code_text, metadata, False

# %%
## Embedding one batch
max_tokens = 8192
batch_size =  20
single_batch = next(chunker(converted_infos, batch_size))
texts = [code_text for code_text, _, skip in map(lambda code: process_data(code, max_tokens), single_batch) if not skip]
embeddings = oa.embeddings(texts)
# Out:
# 2024-02-21 09:59:59,270 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %% [markdown]
# ## ChromaDB (our vector db)

# %%
#chroma run --path /Users/Sana/chromadb   

import chromadb
from chromadb.config import Settings

import chromadb.utils.embedding_functions as embedding_functions
openai_ef = embedding_functions.OpenAIEmbeddingFunction(
                api_key= config2py.config_getter("OPENAI_API_KEY"),
                model_name="text-embedding-3-small"
            )
chroma_client = chromadb.HttpClient(
    settings=Settings(chroma_client_auth_provider="chromadb.auth.token.TokenAuthClientProvider",
                      chroma_client_auth_credentials="test-token"))
chroma_client.heartbeat()  
code_collection = chroma_client.get_or_create_collection(name="rag_sante", metadata={"hnsw:space": "cosine"}, embedding_function=openai_ef)
chroma_client.list_collections() 
## To delete: chroma_client.delete_collection(name="rag_sante")
# Out:
# 2024-02-21 10:54:44,629 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2024-02-21 10:54:44,679 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [Collection(name=rag_sante), Collection(name=rag_jokes)]

# %%
max_tokens = 8192
batch_size = 20
code_chunker = chunker(converted_infos, batch_size)  

for single_batch in code_chunker:
    processed_batch = map(lambda code: process_data(code, max_tokens), single_batch)
    
    valid_chunks = [(code_text, metadata) for code_text, metadata, skip in processed_batch if not skip]

    if valid_chunks:
        texts, metadatas = zip(*valid_chunks)
        ids = [metadata['id'] for metadata in metadatas]

        # embeddings = oa.embeddings(list(texts))

        # for embedding, code_text, code_id, metadata in zip(embeddings, texts, ids, metadatas):
        #     code_collection.add(embeddings=embedding, documents=code_text, ids=code_id, metadatas=metadata)
        for code_text, code_id, metadata in zip(texts, ids, metadatas):
            code_collection.add(documents=code_text, ids=code_id, metadatas=metadata)
# Out:
# 2024-02-21 10:55:16,268 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:25,821 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:26,371 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:26,888 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:27,334 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:27,661 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:28,031 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:28,677 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:28,983 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:29,248 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:29,702 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:30,112 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:30,522 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:31,507 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:31,774 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:34,412 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:34,722 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:35,128 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:36,334 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:36,667 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:37,177 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:37,894 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:38,303 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:39,021 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:39,428 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:39,923 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:40,249 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:40,657 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:40,965 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:41,374 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:41,785 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:42,046 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:42,399 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:42,807 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:45,368 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:45,732 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:46,187 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:46,598 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:47,007 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:47,370 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:47,767 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:48,357 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:48,626 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:51,226 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:51,615 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:52,024 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:52,441 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:57,246 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:57,560 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:57,923 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:58,328 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:58,784 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:59,024 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:58:59,482 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:00,403 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:00,830 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:01,137 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:01,657 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:02,161 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:02,469 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:03,801 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:04,109 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:04,517 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:07,220 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:07,463 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:07,896 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:08,270 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:08,719 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:09,023 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:09,434 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:09,713 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:10,148 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:10,421 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:10,799 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:11,178 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:11,688 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:12,402 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:12,713 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:13,032 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:13,427 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:13,733 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:14,143 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:14,517 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:14,763 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:16,395 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:16,908 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:17,317 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:17,676 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:18,136 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:18,448 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:18,956 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:19,233 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:19,672 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:20,594 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:21,003 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:21,413 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:21,822 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:22,232 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:22,642 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:23,162 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:23,504 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 10:59:23,974 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:02,169 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:16,741 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:17,222 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:17,634 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:17,941 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:18,348 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:18,655 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:18,906 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:19,284 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:19,577 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:19,986 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:20,299 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:20,908 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:21,177 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:21,534 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:21,919 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:22,341 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:22,648 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:22,956 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:23,263 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:23,523 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:23,991 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:24,289 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:24,697 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:25,004 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:25,413 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:25,721 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:26,131 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:29,203 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:29,611 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:30,022 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:30,432 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:30,842 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:31,253 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:32,890 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:33,297 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:39,962 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:40,635 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:41,183 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:41,496 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:41,902 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:42,311 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:42,720 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:43,129 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:43,540 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:44,058 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:44,766 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:45,177 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:45,490 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:45,894 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:46,201 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:46,819 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:47,131 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:47,532 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:48,764 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:49,277 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:49,682 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:50,407 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:51,227 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:51,730 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:52,248 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:52,551 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:52,959 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:53,274 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:53,677 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:54,599 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:57,547 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:57,981 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:58,394 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:58,644 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:00:59,104 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:00,425 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:00,784 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:01,253 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:01,531 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:01,971 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:02,382 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:02,724 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:03,301 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:03,712 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:04,121 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:04,538 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:04,941 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:05,350 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:05,657 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:05,965 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:06,374 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:07,743 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:08,321 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:08,698 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:09,139 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:11,188 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:11,495 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:11,727 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:12,109 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:12,896 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:13,234 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:14,567 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:14,976 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:15,385 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:16,001 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:16,410 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:16,921 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:17,433 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:17,665 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:19,689 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:20,096 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:20,506 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:21,013 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:21,427 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:21,736 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:21,983 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:23,169 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:23,519 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:23,757 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:24,397 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:24,806 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:25,523 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:25,933 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:26,169 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:26,520 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:26,958 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:27,264 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:27,776 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:28,185 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:28,595 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:29,004 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:29,414 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:29,722 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:30,028 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:30,336 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:30,747 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:31,162 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:31,462 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:31,871 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:32,126 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:32,507 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:32,793 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:34,638 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:35,047 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:35,282 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:35,662 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:36,071 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:36,378 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:36,889 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:37,305 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:37,709 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:39,039 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:39,449 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:40,575 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:40,986 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:41,401 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:42,112 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:42,932 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:43,239 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:43,853 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:44,089 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:44,473 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:44,854 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:45,278 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:45,798 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:46,208 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:46,617 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:46,925 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:47,338 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:47,745 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:48,155 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:48,768 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:50,919 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:51,273 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:51,737 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:52,147 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:52,496 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:52,865 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:53,171 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:53,478 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:54,195 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:54,605 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:55,014 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:55,425 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:55,738 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:56,100 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:56,551 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:57,576 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:57,984 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:58,340 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:58,810 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:59,151 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:01:59,520 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:00,031 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:00,441 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:00,749 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:01,056 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:01,569 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:01,978 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:02,336 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:02,592 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:02,906 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:03,198 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:03,821 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:04,171 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:04,407 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:04,846 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:05,357 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:05,767 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:06,073 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:06,484 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:06,893 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:07,303 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:07,713 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:08,122 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:08,532 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:08,773 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:09,147 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:09,863 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:11,097 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:11,501 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:11,751 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:12,218 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:12,626 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:12,935 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:13,177 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:13,529 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:13,856 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:14,223 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:14,466 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:14,881 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:15,768 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:16,110 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:16,518 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:16,928 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:17,166 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:17,401 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:17,643 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:18,055 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:18,568 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:18,874 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:19,291 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:19,647 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:20,020 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:20,382 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:20,820 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:21,172 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:21,536 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:21,946 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:22,363 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:22,765 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:23,175 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:23,545 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:23,795 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:24,024 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:24,265 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:24,609 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:25,224 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:25,860 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:26,248 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:26,658 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:27,067 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:27,483 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:27,783 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:28,193 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:28,603 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:29,012 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:29,318 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:29,833 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:30,189 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:30,554 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:30,854 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:31,096 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:31,368 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:31,777 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:32,289 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:32,698 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:33,108 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:33,881 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:34,384 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:35,360 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:35,695 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:36,061 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:36,384 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:36,794 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:37,203 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:37,613 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:37,965 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:38,330 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:38,564 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:39,151 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:39,458 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:40,072 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:40,481 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:40,795 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:41,915 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:42,272 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:42,938 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:43,177 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:43,554 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:43,866 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:44,269 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:44,782 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:45,088 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:45,607 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:46,010 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:46,318 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:46,728 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:47,034 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:47,446 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:47,754 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:48,162 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:48,571 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:48,987 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:49,287 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:49,697 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:50,106 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:50,823 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 11:02:51,133 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ...
# 2024-02-21 13:42:52,112 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:52,535 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:53,362 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:54,066 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:54,476 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:54,980 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:55,285 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:55,696 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:56,095 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:56,480 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:57,129 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:57,451 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:57,752 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:58,076 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:58,491 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:58,781 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:59,178 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:59,490 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:42:59,791 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:10,376 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:10,850 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:11,260 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:11,779 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:12,285 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:12,537 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:12,897 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:13,254 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:13,719 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:14,128 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:14,484 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:15,154 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:15,598 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:15,876 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:21,605 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:22,533 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:22,964 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:23,444 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:23,856 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:24,265 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-02-21 13:43:24,572 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 19
#      14 # embeddings = oa.embeddings(list(texts))
#      15
#      16 # for embedding, code_text, code_id, metadata in zip(embeddings, texts, ids, metadatas):
#      17 #     code_collection.add(embeddings=embedding, documents=code_text, ids=code_id, metadatas=metadata)
#      18 for code_text, code_id, metadata in zip(texts, ids, metadatas):
# ---> 19     code_collection.add(documents=code_text, ids=code_id, metadatas=metadata)
#
# File ~/Library/Python/3.10/lib/python/site-packages/chromadb/api/models/Collection.py:154, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#     151 if embeddings is None:
#     152     # At this point, we know that one of documents or images are provided from the validation above
#     153     if documents is not None:
# --> 154         embeddings = self._embed(input=documents)
#     155     elif images is not None:
#     156         embeddings = self._embed(input=images)
#
# File ~/Library/Python/3.10/lib/python/site-packages/chromadb/api/models/Collection.py:633, in Collection._embed(self, input)
#     628 if self._embedding_function is None:
#     629     raise ValueError(
#     630         "You must provide an embedding function to compute embeddings."
#     631         "https://docs.trychroma.com/embeddings"
#     632     )
# --> 633 return self._embedding_function(input=input)
#
# File ~/Library/Python/3.10/lib/python/site-packages/chromadb/utils/embedding_functions.py:177, in OpenAIEmbeddingFunction.__call__(self, input)
#     175 # Call the OpenAI Embedding API
#     176 if self._v1:
# --> 177     embeddings = self._client.create(
#     178         input=input, model=self._deployment_id or self._model_name
#     179     ).data
#     181     # Sort resulting embeddings by index
#     182     sorted_embeddings = sorted(
#     183         embeddings, key=lambda e: e.index
#     184     )  # type: ignore
#
# File ~/Library/Python/3.10/lib/python/site-packages/openai/resources/embeddings.py:103, in Embeddings.create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#      97         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#      98             base64.b64decode(data), dtype="float32"
#      99         ).tolist()
#     101     return obj
# --> 103 return self._post(
#     104     "/embeddings",
#     105     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     106     options=make_request_options(
#     107         extra_headers=extra_headers,
#     108         extra_query=extra_query,
#     109         extra_body=extra_body,
#     110         timeout=timeout,
#     111         post_parser=parser,
#     112     ),
#     113     cast_to=CreateEmbeddingResponse,
#     114 )
#
# File ~/Library/Python/3.10/lib/python/site-packages/openai/_base_client.py:1112, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1098 def post(
#    1099     self,
#    1100     path: str,
#    (...)
#    1107     stream_cls: type[_StreamT] | None = None,
#    1108 ) -> ResponseT | _StreamT:
#    1109     opts = FinalRequestOptions.construct(
#    1110         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1111     )
# -> 1112     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/Python/3.10/lib/python/site-packages/openai/_base_client.py:859, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     850 def request(
#     851     self,
#     852     cast_to: Type[ResponseT],
#    (...)
#     857     stream_cls: type[_StreamT] | None = None,
#     858 ) -> ResponseT | _StreamT:
# --> 859     return self._request(
#     860         cast_to=cast_to,
#     861         options=options,
#     862         stream=stream,
#     863         stream_cls=stream_cls,
#     864         remaining_retries=remaining_retries,
#     865     )
#
# File ~/Library/Python/3.10/lib/python/site-packages/openai/_base_client.py:887, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     884     kwargs["auth"] = self.custom_auth
#     886 try:
# --> 887     response = self._client.send(
#     888         request,
#     889         stream=stream or self._should_stream_response_body(request=request),
#     890         **kwargs,
#     891     )
#     892 except httpx.TimeoutException as err:
#     893     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     907 follow_redirects = (
#     908     self.follow_redirects
#     909     if isinstance(follow_redirects, UseClientDefault)
#     910     else follow_redirects
#     911 )
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#     922     if not stream:
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     940 request = next(auth_flow)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#     949         try:
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977 for hook in self._event_hooks["request"]:
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#     982     for hook in self._event_hooks["response"]:
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1011     raise RuntimeError(
#    1012         "Attempted to send an async request with a sync Client instance."
#    1013     )
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#    1020 response.request = request
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#     235 return Response(
#     236     status_code=resp.status,
#     237     headers=resp.headers,
#     238     stream=ResponseStream(resp.stream),
#     239     extensions=resp.extensions,
#     240 )
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Library/Python/3.10/lib/python/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# code_collection.get(include=['embeddings', 'documents', 'metadatas'])
